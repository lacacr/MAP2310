# %%
from Plot_Function import tangent_plane_with_concavity, tangent_plane
import numpy as np

# %%
f = lambda x, y: (x+2*y)*(x-y)

conc = lambda x, y: x**3 - 4*(x**2) + 2*x + (x**2)*y + 4*x*y - 2*x*(y**2) - 8*(y**2) + y

# %%
tangent_plane_with_concavity(f, (-4,-4), (4,4), (0.25,0.25), conc)
